# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno
import plotly.express as px
from scipy.stats import zscore
from sklearn.impute import KNNImputer
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score, accuracy_score, f1_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression  
from sklearn.svm import SVC  
from sklearn.preprocessing import StandardScaler  
import os

# %% [markdown]
# # Planning and Data Understanding & EDA
# # for HBN.csv

# %%
# Read the data
df = pd.read_csv('HBN.csv', index_col=False)

# Drop the first column
df.drop(columns=['Unnamed: 0'], inplace=True)

# Check the data information
df.info()

# Check the table
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3960 entries, 0 to 3959
# Data columns (total 82 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   id                                      3960 non-null   object
#  1   Enrol_Season                            3960 non-null   object
#  2   Age                                     3960 non-null   int64
#  3   Sex                                     3960 non-null   int64
#  4   CGAS-Season                             2555 non-null   object
#  5   CGAS-Score                              2421 non-null   float64
#  6   Physical-Season                         3310 non-null   object
#  7   Physical-BMI                            3022 non-null   float64
#  8   Physical-Height                         3027 non-null   float64
#  9   Physical-Weight                         3076 non-null   float64
#  10  Physical-Waist_Circumference            898 non-null    float64
#  11  Physical-Diastolic_BP                   2954 non-null   float64
#  12  Physical-HeartRate                      2967 non-null   float64
#  13  Physical-Systolic_BP                    2954 non-null   float64
#  14  FE-Season                               1308 non-null   object
#  15  FE-Max_Stage                            743 non-null    float64
#  16  FE-Time_Mins                            740 non-null    float64
#  17  FE-Time_Sec                             740 non-null    float64
#  18  FGC-Season                              3346 non-null   object
#  19  FGC-FGC_CU                              2322 non-null   float64
#  20  FGC-FGC_CU_Zone                         2282 non-null   float64
#  21  FGC-FGC_GSND                            1074 non-null   float64
#  22  FGC-FGC_GSND_Zone                       1062 non-null   float64
#  23  FGC-FGC_GSD                             1074 non-null   float64
#  24  FGC-FGC_GSD_Zone                        1063 non-null   float64
#  25  FGC-FGC_PU                              2310 non-null   float64
#  26  FGC-FGC_PU_Zone                         2271 non-null   float64
#  27  FGC-FGC_SRL                             2305 non-null   float64
#  28  FGC-FGC_SRL_Zone                        2267 non-null   float64
#  29  FGC-FGC_SRR                             2307 non-null   float64
#  30  FGC-FGC_SRR_Zone                        2269 non-null   float64
#  31  FGC-FGC_TL                              2324 non-null   float64
#  32  FGC-FGC_TL_Zone                         2285 non-null   float64
#  33  BIA-Season                              2145 non-null   object
#  34  BIA-BIA_Activity_Level_num              1991 non-null   float64
#  35  BIA-BIA_BMC                             1991 non-null   float64
#  36  BIA-BIA_BMI                             1991 non-null   float64
#  37  BIA-BIA_BMR                             1991 non-null   float64
#  38  BIA-BIA_DEE                             1991 non-null   float64
#  39  BIA-BIA_ECW                             1991 non-null   float64
#  40  BIA-BIA_FFM                             1991 non-null   float64
#  41  BIA-BIA_FFMI                            1991 non-null   float64
#  42  BIA-BIA_FMI                             1991 non-null   float64
#  43  BIA-BIA_Fat                             1991 non-null   float64
#  44  BIA-BIA_Frame_num                       1991 non-null   float64
#  45  BIA-BIA_ICW                             1991 non-null   float64
#  46  BIA-BIA_LDM                             1991 non-null   float64
#  47  BIA-BIA_LST                             1991 non-null   float64
#  48  BIA-BIA_SMM                             1991 non-null   float64
#  49  BIA-BIA_TBW                             1991 non-null   float64
#  50  PAQ_A-Season                            475 non-null    object
#  51  PAQ_A-PAQ_A_Total                       475 non-null    float64
#  52  PAQ_C-Season                            1721 non-null   object
#  53  PAQ_C-PAQ_C_Total                       1721 non-null   float64
#  54  PCIAT-Season                            2736 non-null   object
#  55  PCIAT-PCIAT_01                          2733 non-null   float64
#  56  PCIAT-PCIAT_02                          2734 non-null   float64
#  57  PCIAT-PCIAT_03                          2731 non-null   float64
#  58  PCIAT-PCIAT_04                          2731 non-null   float64
#  59  PCIAT-PCIAT_05                          2729 non-null   float64
#  60  PCIAT-PCIAT_06                          2732 non-null   float64
#  61  PCIAT-PCIAT_07                          2729 non-null   float64
#  62  PCIAT-PCIAT_08                          2730 non-null   float64
#  63  PCIAT-PCIAT_09                          2730 non-null   float64
#  64  PCIAT-PCIAT_10                          2733 non-null   float64
#  65  PCIAT-PCIAT_11                          2734 non-null   float64
#  66  PCIAT-PCIAT_12                          2731 non-null   float64
#  67  PCIAT-PCIAT_13                          2729 non-null   float64
#  68  PCIAT-PCIAT_14                          2732 non-null   float64
#  69  PCIAT-PCIAT_15                          2730 non-null   float64
#  70  PCIAT-PCIAT_16                          2728 non-null   float64
#  71  PCIAT-PCIAT_17                          2725 non-null   float64
#  72  PCIAT-PCIAT_18                          2728 non-null   float64
#  73  PCIAT-PCIAT_19                          2730 non-null   float64
#  74  PCIAT-PCIAT_20                          2733 non-null   float64
#  75  PCIAT-PCIAT_Total                       2736 non-null   float64
#  76  SDS-Season                              2618 non-null   object
#  77  SDS-SDS_Total_Raw                       2609 non-null   float64
#  78  SDS-SDS_Total_T                         2606 non-null   float64
#  79  PreInt_EduHx-Season                     3540 non-null   object
#  80  PreInt_EduHx-computerinternet_hoursday  3301 non-null   float64
#  81  sii                                     2736 non-null   float64
# dtypes: float64(68), int64(2), object(12)
# memory usage: 2.5+ MB
#             id Enrol_Season  Age  Sex CGAS-Season  CGAS-Score Physical-Season  \
# 0     00008ff9         Fall    5    0      Winter        51.0            Fall
# 1     000fd460       Summer    9    0         NaN         NaN            Fall
# 2     00105258       Summer   10    1        Fall        71.0            Fall
# 3     00115b9f       Winter    9    0        Fall        71.0          Summer
# 4     0016bb22       Spring   18    1      Summer         NaN             NaN
# ...        ...          ...  ...  ...         ...         ...             ...
# 3955  ff8a2de4         Fall   13    0      Spring        60.0            Fall
# 3956  ffa9794a       Winter   10    0         NaN         NaN          Spring
# 3957  ffcd4dbd         Fall   11    0      Spring        68.0          Winter
# 3958  ffed1dd5       Spring   13    0      Spring        70.0          Winter
# 3959  ffef538e       Spring   11    0         NaN         NaN          Winter
#
#       Physical-BMI  Physical-Height  Physical-Weight  ...  PCIAT-PCIAT_18  \
# 0        16.877316             46.0             50.8  ...             4.0
# 1        14.035590             48.0             46.0  ...             0.0
# 2        16.648696             56.5             75.6  ...             2.0
# 3        18.292347             56.0             81.6  ...             3.0
# 4              NaN              NaN              NaN  ...             NaN
# ...            ...              ...              ...  ...             ...
# 3955     16.362460             59.5             82.4  ...             1.0
# 3956     18.764678             53.5             76.4  ...             NaN
# 3957     21.441500             60.0            109.8  ...             1.0
# 3958     12.235895             70.7             87.0  ...             1.0
# 3959           NaN              NaN              NaN  ...             NaN
#
#       PCIAT-PCIAT_19  PCIAT-PCIAT_20  PCIAT-PCIAT_Total SDS-Season  \
# 0                2.0             4.0               55.0        NaN
# 1                0.0             0.0                0.0       Fall
# 2                1.0             1.0               28.0       Fall
# 3                4.0             1.0               44.0     Summer
# 4                NaN             NaN                NaN        NaN
# ...              ...             ...                ...        ...
# 3955             1.0             0.0               32.0     Winter
# 3956             NaN             NaN                NaN        NaN
# 3957             0.0             1.0               31.0     Winter
# 3958             1.0             1.0               19.0     Spring
# 3959             NaN             NaN                NaN        NaN
#
#       SDS-SDS_Total_Raw  SDS-SDS_Total_T  PreInt_EduHx-Season  \
# 0                   NaN              NaN                 Fall
# 1                  46.0             64.0               Summer
# 2                  38.0             54.0               Summer
# 3                  31.0             45.0               Winter
# 4                   NaN              NaN                  NaN
# ...                 ...              ...                  ...
# 3955               35.0             50.0                 Fall
# 3956                NaN              NaN               Winter
# 3957               56.0             77.0                 Fall
# 3958               33.0             47.0               Spring
# 3959                NaN              NaN               Spring
#
#      PreInt_EduHx-computerinternet_hoursday  sii
# 0                                       3.0  2.0
# 1                                       0.0  0.0
# 2                                       2.0  0.0
# 3                                       0.0  1.0
# 4                                       NaN  NaN
# ...                                     ...  ...
# 3955                                    1.0  1.0
# 3956                                    0.0  NaN
# 3957                                    0.0  1.0
# 3958                                    1.0  0.0
# 3959                                    1.0  NaN
#
# [3960 rows x 82 columns]

# %%
# Check the distribution of the some variables
columns_to_plot = ['Age', 'Physical-Weight', 'Physical-Height', 'Sex',] 
num_columns = len(columns_to_plot)  
fig, axes = plt.subplots(nrows=1, ncols=num_columns, figsize=(20, 5))  

for i, column in enumerate(columns_to_plot):  
    if column == 'Sex':  
        sns.countplot(x=column, data=df, ax=axes[i])
        axes[i].set_xticklabels(['Male', 'Female'])
        axes[i].set_title(f'Distribution of {column}')  
        axes[i].set_xlabel('Category')  
        axes[i].set_ylabel('Count')  
    else:  
        sns.kdeplot(df[column], ax=axes[i], fill=True, alpha=0.5)  
        axes[i].set_title(f'Distribution of {column}')  
        axes[i].set_xlabel('Value')  
        axes[i].set_ylabel('Density')  

plt.tight_layout()  
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_11392\1323648986.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[i].set_xticklabels(['Male', 'Female'])

# %%
msno.matrix(df)
plt.show()

# %%
# Check the number and percentage of missing values
missing_values = df.isnull().sum()
missing_percentage = (df.isnull().sum() / len(df)) * 100
missing_data = pd.DataFrame({'Missing Values': missing_values, 'Percentage': missing_percentage})
missing_data
# Out:
#                                         Missing Values  Percentage
# id                                                   0    0.000000
# Enrol_Season                                         0    0.000000
# Age                                                  0    0.000000
# Sex                                                  0    0.000000
# CGAS-Season                                       1405   35.479798
# ...                                                ...         ...
# SDS-SDS_Total_Raw                                 1351   34.116162
# SDS-SDS_Total_T                                   1354   34.191919
# PreInt_EduHx-Season                                420   10.606061
# PreInt_EduHx-computerinternet_hoursday             659   16.641414
# sii                                               1224   30.909091
#
# [82 rows x 2 columns]

# %%
df[['Physical-BMI', 'BIA-BIA_BMI']] # Values are the same but Physical-BMI has less Nan Values
# Out:
#       Physical-BMI  BIA-BIA_BMI
# 0        16.877316      16.8792
# 1        14.035590      14.0371
# 2        16.648696          NaN
# 3        18.292347      18.2943
# 4              NaN          NaN
# ...            ...          ...
# 3955     16.362460      16.3642
# 3956     18.764678          NaN
# 3957     21.441500      21.4438
# 3958     12.235895      12.2372
# 3959           NaN          NaN
#
# [3960 rows x 2 columns]

# %%
# Select only numeric columns
numeric_df = df.select_dtypes(include=[np.number])

# Plot the heatmap to check the correlation between the variables
corr_df = numeric_df.corr().abs()
plt.figure(figsize=(20, 20))
sns.heatmap(corr_df, annot=False, cmap=['blue', 'cyan', 'green', 'yellow', 'red'], linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %%
# Identify columns that have more than 70% correlation with the target variable
sii_corr = numeric_df.corr()['sii'].abs()
sii_corr = sii_corr[sii_corr > 0.7].sort_values(ascending=False)
sii_corr
# Out:
# sii                  1.000000
# PCIAT-PCIAT_Total    0.899681
# PCIAT-PCIAT_15       0.751399
# PCIAT-PCIAT_18       0.731112
# PCIAT-PCIAT_17       0.729867
# PCIAT-PCIAT_05       0.722722
# PCIAT-PCIAT_13       0.705679
# PCIAT-PCIAT_20       0.703013
# Name: sii, dtype: float64

# %%
# Identify columns that have more than 70% correlation with the target variable
t_corr = numeric_df.corr()['SDS-SDS_Total_T'].abs()
t_corr = t_corr[t_corr > 0.7].sort_values(ascending=False)
t_corr
# Out:
# SDS-SDS_Total_T      1.000000
# SDS-SDS_Total_Raw    0.996134
# Name: SDS-SDS_Total_T, dtype: float64

# %%
# Distribution of the target variable
sns.histplot(df['sii'], kde=True)
plt.title('Distribution of Target Variable (sii)')
plt.show()

# %%
# Boxplot for outlier detection

sns.boxplot(df['sii'])
plt.title(f'Boxplot of "sii" column')
plt.show()

# %% [markdown]
# # Data Preprocessing #

# %%
# Ensure that the main data is not changed
df_data = df.copy()

# Remove the id column
# df_data.drop(columns=['id'], inplace=True)

# Remove PCIAT-related columns
PCIAT_columns = []
for column in df.columns:
    if 'PCIAT' in column:
        PCIAT_columns.append(column)

df_data = df_data.drop(columns=PCIAT_columns, errors='ignore')

#Remove the columns that have more than 50% missing values
df_data = df_data.dropna(thresh=len(df) * 0.5, axis=1)

# Remove the rows that have more than 70% missing values
df_data = df_data.dropna(thresh=df_data.shape[1] * 0.3, axis=0)

# Check the shape of the data after removing the columns and rows
df_data.shape
# Out:
# (3041, 47)

# %%
# Select the columns that contain the season information
season_columns = []
for column in df_data.columns:
    if 'Season' in column:
        season_columns.append(column)

# Define equivalent numerical values for each season
season_mapping = {'Spring': 0, 'Summer': 1, 'Fall': 2, 'Winter': 3}

# Change the season values to numerical values
for column in season_columns:
    df_data[column] = df_data[column].apply(lambda x: season_mapping.get(x) if pd.notna(x) else x)

# Check the data information after encoding
df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3041 entries, 0 to 3958
# Data columns (total 47 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   id                                      3041 non-null   object
#  1   Enrol_Season                            3041 non-null   int64
#  2   Age                                     3041 non-null   int64
#  3   Sex                                     3041 non-null   int64
#  4   CGAS-Season                             2262 non-null   float64
#  5   CGAS-Score                              2256 non-null   float64
#  6   Physical-Season                         3020 non-null   float64
#  7   Physical-BMI                            2962 non-null   float64
#  8   Physical-Height                         2967 non-null   float64
#  9   Physical-Weight                         2999 non-null   float64
#  10  Physical-Diastolic_BP                   2903 non-null   float64
#  11  Physical-HeartRate                      2915 non-null   float64
#  12  Physical-Systolic_BP                    2903 non-null   float64
#  13  FGC-Season                              2920 non-null   float64
#  14  FGC-FGC_CU                              2322 non-null   float64
#  15  FGC-FGC_CU_Zone                         2282 non-null   float64
#  16  FGC-FGC_PU                              2310 non-null   float64
#  17  FGC-FGC_PU_Zone                         2271 non-null   float64
#  18  FGC-FGC_SRL                             2305 non-null   float64
#  19  FGC-FGC_SRL_Zone                        2267 non-null   float64
#  20  FGC-FGC_SRR                             2307 non-null   float64
#  21  FGC-FGC_SRR_Zone                        2269 non-null   float64
#  22  FGC-FGC_TL                              2324 non-null   float64
#  23  FGC-FGC_TL_Zone                         2285 non-null   float64
#  24  BIA-Season                              2145 non-null   float64
#  25  BIA-BIA_Activity_Level_num              1991 non-null   float64
#  26  BIA-BIA_BMC                             1991 non-null   float64
#  27  BIA-BIA_BMI                             1991 non-null   float64
#  28  BIA-BIA_BMR                             1991 non-null   float64
#  29  BIA-BIA_DEE                             1991 non-null   float64
#  30  BIA-BIA_ECW                             1991 non-null   float64
#  31  BIA-BIA_FFM                             1991 non-null   float64
#  32  BIA-BIA_FFMI                            1991 non-null   float64
#  33  BIA-BIA_FMI                             1991 non-null   float64
#  34  BIA-BIA_Fat                             1991 non-null   float64
#  35  BIA-BIA_Frame_num                       1991 non-null   float64
#  36  BIA-BIA_ICW                             1991 non-null   float64
#  37  BIA-BIA_LDM                             1991 non-null   float64
#  38  BIA-BIA_LST                             1991 non-null   float64
#  39  BIA-BIA_SMM                             1991 non-null   float64
#  40  BIA-BIA_TBW                             1991 non-null   float64
#  41  SDS-Season                              2417 non-null   float64
#  42  SDS-SDS_Total_Raw                       2417 non-null   float64
#  43  SDS-SDS_Total_T                         2414 non-null   float64
#  44  PreInt_EduHx-Season                     2993 non-null   float64
#  45  PreInt_EduHx-computerinternet_hoursday  2913 non-null   float64
#  46  sii                                     2575 non-null   float64
# dtypes: float64(43), int64(3), object(1)
# memory usage: 1.1+ MB

# %%
# Fill the missing values of the season columns by the mode function
for column in season_columns:
    if column in df_data.columns and (df_data[column].isnull().sum() > 0):
        df_data[column] = df_data[column].fillna(df_data[column].mode()[0])
        df_data[column] = df_data[column].astype(int)  # Convert the column to integer (similar to other season columns)

## Ensure that only numeric columns are selected
numeric_columns = df_data.select_dtypes(include=['float64']).columns

# Fill NaN values in other columns by KNN Imputation
imputer_algorithm = KNNImputer(n_neighbors=5, weights='uniform', metric='nan_euclidean')
df_data[numeric_columns] = imputer_algorithm.fit_transform(df_data[numeric_columns])

# Check the data information after imputation
df_data.info()
df_data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3041 entries, 0 to 3958
# Data columns (total 47 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   id                                      3041 non-null   object
#  1   Enrol_Season                            3041 non-null   int64
#  2   Age                                     3041 non-null   int64
#  3   Sex                                     3041 non-null   int64
#  4   CGAS-Season                             3041 non-null   int32
#  5   CGAS-Score                              3041 non-null   float64
#  6   Physical-Season                         3041 non-null   int32
#  7   Physical-BMI                            3041 non-null   float64
#  8   Physical-Height                         3041 non-null   float64
#  9   Physical-Weight                         3041 non-null   float64
#  10  Physical-Diastolic_BP                   3041 non-null   float64
#  11  Physical-HeartRate                      3041 non-null   float64
#  12  Physical-Systolic_BP                    3041 non-null   float64
#  13  FGC-Season                              3041 non-null   int32
#  14  FGC-FGC_CU                              3041 non-null   float64
#  15  FGC-FGC_CU_Zone                         3041 non-null   float64
#  16  FGC-FGC_PU                              3041 non-null   float64
#  17  FGC-FGC_PU_Zone                         3041 non-null   float64
#  18  FGC-FGC_SRL                             3041 non-null   float64
#  19  FGC-FGC_SRL_Zone                        3041 non-null   float64
#  20  FGC-FGC_SRR                             3041 non-null   float64
#  21  FGC-FGC_SRR_Zone                        3041 non-null   float64
#  22  FGC-FGC_TL                              3041 non-null   float64
#  23  FGC-FGC_TL_Zone                         3041 non-null   float64
#  24  BIA-Season                              3041 non-null   int32
#  25  BIA-BIA_Activity_Level_num              3041 non-null   float64
#  26  BIA-BIA_BMC                             3041 non-null   float64
#  27  BIA-BIA_BMI                             3041 non-null   float64
#  28  BIA-BIA_BMR                             3041 non-null   float64
#  29  BIA-BIA_DEE                             3041 non-null   float64
#  30  BIA-BIA_ECW                             3041 non-null   float64
#  31  BIA-BIA_FFM                             3041 non-null   float64
#  32  BIA-BIA_FFMI                            3041 non-null   float64
#  33  BIA-BIA_FMI                             3041 non-null   float64
#  34  BIA-BIA_Fat                             3041 non-null   float64
#  35  BIA-BIA_Frame_num                       3041 non-null   float64
#  36  BIA-BIA_ICW                             3041 non-null   float64
#  37  BIA-BIA_LDM                             3041 non-null   float64
#  38  BIA-BIA_LST                             3041 non-null   float64
#  39  BIA-BIA_SMM                             3041 non-null   float64
#  40  BIA-BIA_TBW                             3041 non-null   float64
#  41  SDS-Season                              3041 non-null   int32
#  42  SDS-SDS_Total_Raw                       3041 non-null   float64
#  43  SDS-SDS_Total_T                         3041 non-null   float64
#  44  PreInt_EduHx-Season                     3041 non-null   int32
#  45  PreInt_EduHx-computerinternet_hoursday  3041 non-null   float64
#  46  sii                                     3041 non-null   float64
# dtypes: float64(37), int32(6), int64(3), object(1)
# memory usage: 1.0+ MB
#             id  Enrol_Season  Age  Sex  CGAS-Season  CGAS-Score  \
# 0     00008ff9             2    5    0            3        51.0
# 1     000fd460             1    9    0            0        52.4
# 2     00105258             1   10    1            2        71.0
# 3     00115b9f             3    9    0            2        71.0
# 5     001f3379             0   13    1            3        50.0
# ...        ...           ...  ...  ...          ...         ...
# 3954  ff759544             1    7    1            0        65.4
# 3955  ff8a2de4             2   13    0            0        60.0
# 3956  ffa9794a             3   10    0            0        62.2
# 3957  ffcd4dbd             2   11    0            0        68.0
# 3958  ffed1dd5             0   13    0            0        70.0
#
#       Physical-Season  Physical-BMI  Physical-Height  Physical-Weight  ...  \
# 0                   2     16.877316             46.0             50.8  ...
# 1                   2     14.035590             48.0             46.0  ...
# 2                   2     16.648696             56.5             75.6  ...
# 3                   1     18.292347             56.0             81.6  ...
# 5                   1     22.279952             59.5            112.2  ...
# ...               ...           ...              ...              ...  ...
# 3954                1     13.927006             48.5             46.6  ...
# 3955                2     16.362460             59.5             82.4  ...
# 3956                0     18.764678             53.5             76.4  ...
# 3957                3     21.441500             60.0            109.8  ...
# 3958                3     12.235895             70.7             87.0  ...
#
#       BIA-BIA_LDM  BIA-BIA_LST  BIA-BIA_SMM  BIA-BIA_TBW  SDS-Season  \
# 0         8.89536     38.91770     19.54130     32.69090           0
# 1        14.97400     39.44970     15.41070     27.05520           2
# 2        14.64446     56.55906     25.66322     45.73390           2
# 3        16.77900     58.93380     26.47980     45.99660           1
# 5        20.90200     79.69820     35.38040     63.12650           1
# ...           ...          ...          ...          ...         ...
# 3954     15.14000     42.81850     18.09370     30.04530           1
# 3955     17.97970     66.28890     29.77900     52.83200           3
# 3956     16.69382     53.62294     23.48328     41.54076           0
# 3957     21.34030     71.39030     28.77920     54.46300           3
# 3958     25.00540     86.24750     45.43400     67.90380           0
#
#       SDS-SDS_Total_Raw  SDS-SDS_Total_T  PreInt_EduHx-Season  \
# 0                  36.2             51.4                    2
# 1                  46.0             64.0                    1
# 2                  38.0             54.0                    1
# 3                  31.0             45.0                    3
# 5                  40.0             56.0                    0
# ...                 ...              ...                  ...
# 3954               48.0             67.0                    1
# 3955               35.0             50.0                    2
# 3956               38.2             54.2                    3
# 3957               56.0             77.0                    2
# 3958               33.0             47.0                    0
#
#       PreInt_EduHx-computerinternet_hoursday  sii
# 0                                        3.0  2.0
# 1                                        0.0  0.0
# 2                                        2.0  0.0
# 3                                        0.0  1.0
# 5                                        0.0  1.0
# ...                                      ...  ...
# 3954                                     0.0  1.0
# 3955                                     1.0  1.0
# 3956                                     0.0  0.4
# 3957                                     0.0  1.0
# 3958                                     1.0  0.0
#
# [3041 rows x 47 columns]

# %%
# Manage outliers
for column in numeric_columns:
    if len(df_data[column].unique()) > 20:
        z_scores = np.abs(zscore(df_data[column]))
        outliers = df_data.index[z_scores > 3]
        df_data = df_data.drop(index=outliers)


## Outliers detection with the following functions
# def zscore_detector(data):
#     z_scores = np.abs(zscore(data))
#     return data.index[z_scores > 3].tolist()

# def iqr_detector(data):
#     q1 = np.percentile(data, 25)
#     q3 = np.percentile(data, 75)
#     iqr = q3 - q1
#     lower_range = q1 - 1.5 * iqr
#     upper_range = q3 + 1.5 * iqr
#     return data.index[(data < lower_range) | (data > upper_range)].tolist()

# # Detect and drop outliers
# for column in numeric_columns:
#     if len(df_data[column].unique()) > 20:
#         outliers = zscore_detector(df_data[column])
#         df_data = df_data.drop(index=outliers)
#     else:
#         outliers = iqr_detector(df_data[column])
#         df_data = df_data.drop(index=outliers)

# Check final information
df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2256 entries, 0 to 3958
# Data columns (total 47 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   id                                      2256 non-null   object
#  1   Enrol_Season                            2256 non-null   int64
#  2   Age                                     2256 non-null   int64
#  3   Sex                                     2256 non-null   int64
#  4   CGAS-Season                             2256 non-null   int32
#  5   CGAS-Score                              2256 non-null   float64
#  6   Physical-Season                         2256 non-null   int32
#  7   Physical-BMI                            2256 non-null   float64
#  8   Physical-Height                         2256 non-null   float64
#  9   Physical-Weight                         2256 non-null   float64
#  10  Physical-Diastolic_BP                   2256 non-null   float64
#  11  Physical-HeartRate                      2256 non-null   float64
#  12  Physical-Systolic_BP                    2256 non-null   float64
#  13  FGC-Season                              2256 non-null   int32
#  14  FGC-FGC_CU                              2256 non-null   float64
#  15  FGC-FGC_CU_Zone                         2256 non-null   float64
#  16  FGC-FGC_PU                              2256 non-null   float64
#  17  FGC-FGC_PU_Zone                         2256 non-null   float64
#  18  FGC-FGC_SRL                             2256 non-null   float64
#  19  FGC-FGC_SRL_Zone                        2256 non-null   float64
#  20  FGC-FGC_SRR                             2256 non-null   float64
#  21  FGC-FGC_SRR_Zone                        2256 non-null   float64
#  22  FGC-FGC_TL                              2256 non-null   float64
#  23  FGC-FGC_TL_Zone                         2256 non-null   float64
#  24  BIA-Season                              2256 non-null   int32
#  25  BIA-BIA_Activity_Level_num              2256 non-null   float64
#  26  BIA-BIA_BMC                             2256 non-null   float64
#  27  BIA-BIA_BMI                             2256 non-null   float64
#  28  BIA-BIA_BMR                             2256 non-null   float64
#  29  BIA-BIA_DEE                             2256 non-null   float64
#  30  BIA-BIA_ECW                             2256 non-null   float64
#  31  BIA-BIA_FFM                             2256 non-null   float64
#  32  BIA-BIA_FFMI                            2256 non-null   float64
#  33  BIA-BIA_FMI                             2256 non-null   float64
#  34  BIA-BIA_Fat                             2256 non-null   float64
#  35  BIA-BIA_Frame_num                       2256 non-null   float64
#  36  BIA-BIA_ICW                             2256 non-null   float64
#  37  BIA-BIA_LDM                             2256 non-null   float64
#  38  BIA-BIA_LST                             2256 non-null   float64
#  39  BIA-BIA_SMM                             2256 non-null   float64
#  40  BIA-BIA_TBW                             2256 non-null   float64
#  41  SDS-Season                              2256 non-null   int32
#  42  SDS-SDS_Total_Raw                       2256 non-null   float64
#  43  SDS-SDS_Total_T                         2256 non-null   float64
#  44  PreInt_EduHx-Season                     2256 non-null   int32
#  45  PreInt_EduHx-computerinternet_hoursday  2256 non-null   float64
#  46  sii                                     2256 non-null   float64
# dtypes: float64(37), int32(6), int64(3), object(1)
# memory usage: 793.1+ KB

# %% [markdown]
# ### Feature Engineering

# %%
# Ignore columns that have less than %10 correlation with target columns
df_train = df_data[df_data.corr()['sii'][df_data.corr()['sii'].abs() > 0.1].index.tolist()]
df_train
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[48], line 2
#       1 # Ignore columns that have less than %10 correlation with target columns
# ----> 2 df_train = df_data[df_data.corr()['sii'][df_data.corr()['sii'].abs() > 0.1].index.tolist()]
#       3 df_train
#
# File c:\Users\user\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\frame.py:10054, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10052 cols = data.columns
#   10053 idx = cols.copy()
# > 10054 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10056 if method == "pearson":
#   10057     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\Users\user\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\frame.py:1838, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1836 if dtype is not None:
#    1837     dtype = np.dtype(dtype)
# -> 1838 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1839 if result.dtype is not dtype:
#    1840     result = np.array(result, dtype=dtype, copy=False)
#
# File c:\Users\user\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\internals\managers.py:1732, in BlockManager.as_array(self, dtype, copy, na_value)
#    1730         arr.flags.writeable = False
#    1731 else:
# -> 1732     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1733     # The underlying data was copied within _interleave, so no need
#    1734     # to further copy if copy=True or setting na_value
#    1736 if na_value is not lib.no_default:
#
# File c:\Users\user\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\internals\managers.py:1794, in BlockManager._interleave(self, dtype, na_value)
#    1792     else:
#    1793         arr = blk.get_values(dtype)
# -> 1794     result[rl.indexer] = arr
#    1795     itemmask[rl.indexer] = 1
#    1797 if not itemmask.all():
#
# ValueError: could not convert string to float: '00008ff9'

# %%
df_train.hist(figsize=(10, 10))
plt.tight_layout()
plt.show()

df_train.boxplot(figsize=(10, 10))
plt.xticks(rotation=45, horizontalalignment='right')
plt.tight_layout()
plt.show()

# %%
# Split the data into X and y variables as features and target variable
X = df_data.drop(columns=['id', 'sii'])
y = df_data['sii'].astype(int)

# %%
X
scaler = StandardScaler()  
X = scaler.fit_transform(X)

# %%
y
# Out:
# 0       2
# 1       0
# 2       0
# 3       1
# 7       1
#        ..
# 3954    1
# 3955    1
# 3956    0
# 3957    1
# 3958    0
# Name: sii, Length: 2256, dtype: int32

# %%
class_counts = df_data['sii'].value_counts()  
print(class_counts)
# Out:
# sii
# 0.0    1272
# 1.0     504
# 2.0     228
# 0.4      79
# 0.2      68
# 0.6      55
# 0.8      30
# 3.0      10
# 1.2       6
# 1.4       4
# Name: count, dtype: int64

# %%
class_counts = y.value_counts()  
print(class_counts)
# Out:
# sii
# 0    1504
# 1     514
# 2     228
# 3      10
# Name: count, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, random_state=42)

# %%
model = RandomForestClassifier(max_depth=10, n_estimators=100)  
model.fit(X_train, y_train)  

y_pred = model.predict(X_test)  

f1_macro = f1_score(y_test, y_pred, average='macro')  
f1_micro = f1_score(y_test, y_pred, average='micro')  
f1_weighted = f1_score(y_test, y_pred, average='weighted')  

print(f'F1 Score (Macro): {f1_macro:.2f}')  
print(f'F1 Score (Micro): {f1_micro:.2f}')  
print(f'F1 Score (Weighted): {f1_weighted:.2f}')
# Out:
# F1 Score (Macro): 0.31
# F1 Score (Micro): 0.72
# F1 Score (Weighted): 0.66

# %%
model = SVC(kernel='rbf', gamma='scale')  

model.fit(X_train, y_train)  

y_pred = model.predict(X_test)  

f1_macro = f1_score(y_test, y_pred, average='macro')  
f1_micro = f1_score(y_test, y_pred, average='micro')  
f1_weighted = f1_score(y_test, y_pred, average='weighted')  

print(f'F1 Score (Macro): {f1_macro:.2f}')  
print(f'F1 Score (Micro): {f1_micro:.2f}')  
print(f'F1 Score (Weighted): {f1_weighted:.2f}')
# Out:
# F1 Score (Macro): 0.26
# F1 Score (Micro): 0.70
# F1 Score (Weighted): 0.62

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %%
# # check the correlation between the variables by using heatmap
# plt.figure(figsize=(20, 15))
# sns.heatmap(df_train.corr(), annot=False, cmap=['blue', 'cyan', 'green', 'yellow', 'red'], linewidths=0.5)
# plt.title('Correlation Heatmap')
# plt.tight_layout()
# plt.show()

# Check the distribution of the sii column
# sns.histplot(df_train['sii'])
# plt.title('Distribution of Target Variable (sii)')
# plt.tight_layout()
# plt.show()

# # Boxplot for outlier detection
# sns.boxplot(df_train['sii'])
# plt.title(f'Boxplot of "sii" column')
# plt.tight_layout()
# plt.show()
# Out:
# C:\Users\ramti\anaconda3\envs\quera\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# correlation_with_target = df_data.corr()['sii'].abs().sort_values(ascending=False)
# correlation_with_target

# %%
# base_folder = '/content/drive/MyDrive/Colab Notebooks/QBC8_AI_project_data_Q1/series.parquet'
# all_features = []

# for folder_name in os.listdir(base_folder):
#     folder_path = os.path.join(base_folder, folder_name)
#     file_path = os.path.join(folder_path, "part-0.parquet")

#     if os.path.isdir(folder_path) and os.path.exists(file_path):
#         try:
#             participant_id = folder_name[3:]

#             accel_data = pd.read_parquet(file_path)

#             # اینجا missing value رو توی هر ستون از فایل مورد نظرت مدیرت کن. یعنی مقادیر گم شده پر کن

#             features = {'id': participant_id}
#             for column in accel_data.select_dtypes(include=[np.number]).columns:
#                 # این پایینی ها مقادیر خروجی از فایل پارکت هستن که میخوایم استخراجشون کنیم و به عنوان نمونه گذاشتم و خودت به صلاحدید خودت مدیریتشون کن
#                 features[f'{column}_mean'] = accel_data[column].mean()
#                 features[f'{column}_std'] = accel_data[column].std()
#                 features[f'{column}_max'] = accel_data[column].max()
#                 features[f'{column}_min'] = accel_data[column].min()
#             all_features.append(features)
#         except Exception as e:
#             print(f"Error {folder_name}: {e}")

# accelerometer_features = pd.DataFrame(all_features)

# %%
acc_enmo = pd.read_csv('accelerometer_enmo.csv')

# %%
final_df = pd.merge(df_data, acc_enmo, on=['id'])
final_df
# Out:
#            id  Enrol_Season  Age  Sex  CGAS-Season  CGAS-Score  \
# 0    00115b9f             3    9    0            2        71.0
# 1    00f332d1             3   14    0            0        68.0
# 2    012cadd8             0    9    0            3        60.0
# 3    012e3869             1    6    0            3        60.0
# 4    029a19c9             3   17    1            0        54.0
# ..        ...           ...  ...  ...          ...         ...
# 719  fe9c71d8             3    9    0            0        80.0
# 720  fecc07d6             2    7    0            0        85.0
# 721  ff18b749             0    7    0            0        55.0
# 722  ffcd4dbd             2   11    0            0        68.0
# 723  ffed1dd5             0   13    0            0        70.0
#
#      Physical-Season  Physical-BMI  Physical-Height  Physical-Weight  ...  \
# 0                  1     18.292347            56.00             81.6  ...
# 1                  0     17.168636            66.50            108.0  ...
# 2                  2     17.089151            53.20             68.8  ...
# 3                  1     18.463594            46.80             24.2  ...
# 4                  0     32.084107            64.25            188.4  ...
# ..               ...           ...              ...              ...  ...
# 719                3     15.891137            56.75             72.8  ...
# 720                3     15.986589            49.00             54.6  ...
# 721                1     14.768842            47.50             47.4  ...
# 722                3     21.441500            60.00            109.8  ...
# 723                3     12.235895            70.70             87.0  ...
#
#      BIA-BIA_TBW  SDS-Season  SDS-SDS_Total_Raw  SDS-SDS_Total_T  \
# 0       45.99660           1               31.0             45.0
# 1       68.68220           0               30.0             43.0
# 2       48.92462           1               27.0             40.0
# 3       37.79220           0               36.8             52.2
# 4       50.50210           0               32.0             46.0
# ..           ...         ...                ...              ...
# 719     44.65900           3               33.0             47.0
# 720     39.31490           3               34.0             49.0
# 721     38.54410           1               62.0             85.0
# 722     54.46300           3               56.0             77.0
# 723     67.90380           0               33.0             47.0
#
#      PreInt_EduHx-Season  PreInt_EduHx-computerinternet_hoursday  sii  \
# 0                      3                                     0.0  1.0
# 1                      3                                     2.0  1.0
# 2                      0                                     0.0  0.0
# 3                      1                                     0.0  0.0
# 4                      3                                     3.0  1.0
# ..                   ...                                     ...  ...
# 719                    3                                     0.0  0.0
# 720                    2                                     0.0  0.0
# 721                    0                                     0.0  0.0
# 722                    2                                     0.0  1.0
# 723                    0                                     1.0  0.0
#
#          enmo1      enmo2      enmo3
# 0    44.846527  44.604200  10.549273
# 1    69.172683  23.107218   7.720099
# 2    63.356277  24.736213  11.907510
# 3    80.560701  14.459059   4.980240
# 4    58.206385  35.573261   6.220353
# ..         ...        ...        ...
# 719  53.846070  34.890803  11.263128
# 720  85.579276  10.530103   3.890621
# 721  57.095869  29.432840  13.471291
# 722  69.113655  24.269035   6.617309
# 723  80.401312  12.194122   7.404566
#
# [724 rows x 50 columns]

# %%
X = final_df.drop(columns=['id', 'sii'])
y = final_df['sii'].astype(int)

# %%
X
# Out:
#      Enrol_Season  Age  Sex  CGAS-Season  CGAS-Score  Physical-Season  \
# 0               3    9    0            2        71.0                1
# 1               3   14    0            0        68.0                0
# 2               0    9    0            3        60.0                2
# 3               1    6    0            3        60.0                1
# 4               3   17    1            0        54.0                0
# ..            ...  ...  ...          ...         ...              ...
# 719             3    9    0            0        80.0                3
# 720             2    7    0            0        85.0                3
# 721             0    7    0            0        55.0                1
# 722             2   11    0            0        68.0                3
# 723             0   13    0            0        70.0                3
#
#      Physical-BMI  Physical-Height  Physical-Weight  Physical-Diastolic_BP  \
# 0       18.292347            56.00             81.6                   60.0
# 1       17.168636            66.50            108.0                   60.0
# 2       17.089151            53.20             68.8                   62.0
# 3       18.463594            46.80             24.2                   73.0
# 4       32.084107            64.25            188.4                   72.0
# ..            ...              ...              ...                    ...
# 719     15.891137            56.75             72.8                   44.0
# 720     15.986589            49.00             54.6                   59.0
# 721     14.768842            47.50             47.4                   58.0
# 722     21.441500            60.00            109.8                   79.0
# 723     12.235895            70.70             87.0                   59.0
#
#      ...  BIA-BIA_SMM  BIA-BIA_TBW  SDS-Season  SDS-SDS_Total_Raw  \
# 0    ...     26.47980     45.99660           1               31.0
# 1    ...     42.10740     68.68220           0               30.0
# 2    ...     27.71512     48.92462           1               27.0
# 3    ...     21.13390     37.79220           0               36.8
# 4    ...     29.46306     50.50210           0               32.0
# ..   ...          ...          ...         ...                ...
# 719  ...     25.83650     44.65900           3               33.0
# 720  ...     21.00460     39.31490           3               34.0
# 721  ...     20.82238     38.54410           1               62.0
# 722  ...     28.77920     54.46300           3               56.0
# 723  ...     45.43400     67.90380           0               33.0
#
#      SDS-SDS_Total_T  PreInt_EduHx-Season  \
# 0               45.0                    3
# 1               43.0                    3
# 2               40.0                    0
# 3               52.2                    1
# 4               46.0                    3
# ..               ...                  ...
# 719             47.0                    3
# 720             49.0                    2
# 721             85.0                    0
# 722             77.0                    2
# 723             47.0                    0
#
#      PreInt_EduHx-computerinternet_hoursday      enmo1      enmo2      enmo3
# 0                                       0.0  44.846527  44.604200  10.549273
# 1                                       2.0  69.172683  23.107218   7.720099
# 2                                       0.0  63.356277  24.736213  11.907510
# 3                                       0.0  80.560701  14.459059   4.980240
# 4                                       3.0  58.206385  35.573261   6.220353
# ..                                      ...        ...        ...        ...
# 719                                     0.0  53.846070  34.890803  11.263128
# 720                                     0.0  85.579276  10.530103   3.890621
# 721                                     0.0  57.095869  29.432840  13.471291
# 722                                     0.0  69.113655  24.269035   6.617309
# 723                                     1.0  80.401312  12.194122   7.404566
#
# [724 rows x 48 columns]

# %%
scaler = StandardScaler()  
X = scaler.fit_transform(X)  
X
# Out:
# array([[ 1.42235828, -0.16388874, -0.72402384, ..., -0.94210081,
#          1.31892259, -0.05308147],
#        [ 1.42235828,  1.59657782, -0.72402384, ...,  0.56019059,
#         -0.5030964 , -0.54373963],
#        [-1.28523347, -0.16388874, -0.72402384, ...,  0.20099137,
#         -0.36502773,  0.18247485],
#        ...,
#        [-1.28523347, -0.86807536, -0.72402384, ..., -0.18562776,
#          0.0330441 ,  0.45367843],
#        [ 0.5198277 ,  0.54029789, -0.72402384, ...,  0.55654525,
#         -0.40462429, -0.73499425],
#        [-1.28523347,  1.24448451, -0.72402384, ...,  1.25362823,
#         -1.42805732, -0.59846186]])

# %%
y
# Out:
# 0      1
# 1      1
# 2      0
# 3      0
# 4      1
#       ..
# 719    0
# 720    0
# 721    0
# 722    1
# 723    0
# Name: sii, Length: 724, dtype: int32

# %%
class_counts = final_df['sii'].value_counts()  
print(class_counts)
# Out:
# sii
# 0.0    455
# 1.0    180
# 2.0     84
# 3.0      5
# Name: count, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, random_state=42)

# %%
from sklearn.model_selection import GridSearchCV  

param_grid = {'n_estimators': [100, 500], 'max_depth': [None, 10, 100]}  
grid = GridSearchCV(RandomForestClassifier(), param_grid, cv=4)  
grid.fit(X_train, y_train)  
print(grid.best_params_)
# Out:
# {'max_depth': None, 'n_estimators': 500}

# %%
model = RandomForestClassifier(max_depth=10, n_estimators=500)  
model.fit(X_train, y_train)  

y_pred = model.predict(X_test)  

f1_macro = f1_score(y_test, y_pred, average='macro')  
f1_micro = f1_score(y_test, y_pred, average='micro')  
f1_weighted = f1_score(y_test, y_pred, average='weighted')  

print(f'F1 Score (Macro): {f1_macro:.2f}')  
print(f'F1 Score (Micro): {f1_micro:.2f}')  
print(f'F1 Score (Weighted): {f1_weighted:.2f}')
# Out:
# F1 Score (Macro): 0.28
# F1 Score (Micro): 0.65
# F1 Score (Weighted): 0.56

# %%
model = SVC(kernel='rbf', gamma='scale')  

model.fit(X_train, y_train)  

y_pred = model.predict(X_test)  

f1_macro = f1_score(y_test, y_pred, average='macro')  
f1_micro = f1_score(y_test, y_pred, average='micro')  
f1_weighted = f1_score(y_test, y_pred, average='weighted')  

print(f'F1 Score (Macro): {f1_macro:.2f}')  
print(f'F1 Score (Micro): {f1_micro:.2f}')  
print(f'F1 Score (Weighted): {f1_weighted:.2f}')
# Out:
# F1 Score (Macro): 0.24
# F1 Score (Micro): 0.63
# F1 Score (Weighted): 0.54

# %%
# from sklearn.model_selection import cross_val_score  

# model = LogisticRegression(solver='liblinear', max_iter=500)
# scores = cross_val_score(model, X, y, cv=4)  
# print(f'Cross-validation scores: {scores}')  

# model = RandomForestClassifier(max_depth=10, n_estimators=100)
# scores = cross_val_score(model, X, y, cv=4)  
# print(f'Cross-validation scores: {scores}')

# %% [markdown]
# # PART 2

# %%
male_df = df[df['Sex'] == 0].copy()
female_df = df[df['Sex'] == 1].copy()

# %%
female_df[female_df['BIA-BIA_BMR'] > 4000] # Outiliers
# Out:
#             id  Enrol_Season  Age  Sex  CGAS-Season  CGAS-Score  \
# 3205  cedf96c5             2    9    1          0.0        50.0
# 3511  e252dcb6             0   13    1          2.0        58.0
#
#       Physical-Season  Physical-BMI  Physical-Height  Physical-Weight  ...  \
# 3205              3.0     16.972291             54.0             70.4  ...
# 3511              0.0     23.605261             61.5            127.0  ...
#
#       PCIAT-PCIAT_18  PCIAT-PCIAT_19  PCIAT-PCIAT_20  PCIAT-PCIAT_Total  \
# 3205             1.0             0.0             0.0               13.0
# 3511             4.0             4.0             4.0               68.0
#
#       SDS-Season  SDS-SDS_Total_Raw  SDS-SDS_Total_T  PreInt_EduHx-Season  \
# 3205         3.0               36.0             51.0                  2.0
# 3511         1.0               48.0             67.0                  0.0
#
#       PreInt_EduHx-computerinternet_hoursday  sii
# 3205                                     0.0  0.0
# 3511                                     3.0  2.0
#
# [2 rows x 82 columns]

# %%
female_df[female_df['CGAS-Score'] > 100] # Outliers
# Out:
#             id  Enrol_Season  Age  Sex  CGAS-Season  CGAS-Score  \
# 2065  83525bbe             2   11    1          3.0       999.0
#
#       Physical-Season  Physical-BMI  Physical-Height  Physical-Weight  ...  \
# 2065              2.0           NaN              NaN              NaN  ...
#
#       PCIAT-PCIAT_18  PCIAT-PCIAT_19  PCIAT-PCIAT_20  PCIAT-PCIAT_Total  \
# 2065             NaN             NaN             NaN                NaN
#
#       SDS-Season  SDS-SDS_Total_Raw  SDS-SDS_Total_T  PreInt_EduHx-Season  \
# 2065         NaN                NaN              NaN                  2.0
#
#       PreInt_EduHx-computerinternet_hoursday  sii
# 2065                                     3.0  NaN
#
# [1 rows x 82 columns]

# %%
# Physical-BMI
# BIA-BIA_BMI
# شاخص توده‌ی بدنی
# BIA-BIA_BMR
# نرخ متابولیسم پایه
# CGAS-Score
# معیار کلی میزان عملکرد ذهنی افراد زیر ۱۸ سال


female_df = female_df[female_df['CGAS-Score'] < 100] # Outliers
female_df = female_df[female_df['BIA-BIA_BMR'] < 4000]

columns_to_plot = ['Physical-BMI', 'BIA-BIA_BMR', 'CGAS-Score']
num_columns = len(columns_to_plot)  
fig, axes = plt.subplots(nrows=1, ncols=num_columns, figsize=(20, 5))  
for i, column in enumerate(columns_to_plot):  
        sns.kdeplot(male_df[column], ax=axes[i], fill=True, alpha=0.5, color='red')  
        axes[i].set_title(f'Distribution of {column} / Male')  
        axes[i].set_xlabel('Value')  
        axes[i].set_ylabel('Density')  
plt.tight_layout()  
plt.show()  

fig, axes = plt.subplots(nrows=1, ncols=num_columns, figsize=(20, 5))  
for i, column in enumerate(columns_to_plot):  
        sns.kdeplot(female_df[column], ax=axes[i], fill=True, alpha=0.5)  
        axes[i].set_title(f'Distribution of {column} / Female')  
        axes[i].set_xlabel('Value')  
        axes[i].set_ylabel('Density')  
plt.tight_layout()  
plt.show()
# Out:
# C:\Users\ramti\anaconda3\envs\quera\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\ramti\anaconda3\envs\quera\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\ramti\anaconda3\envs\quera\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\ramti\anaconda3\envs\quera\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\ramti\anaconda3\envs\quera\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\ramti\anaconda3\envs\quera\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
male_df.describe()
# Out:
#                Age     Sex   CGAS-Score  Physical-BMI  Physical-Height  \
# count  2484.000000  2484.0  1553.000000   1920.000000      1922.000000
# mean     10.257246     0.0    64.194462     19.232013        56.028606
# std       3.481302     0.0    11.365906      4.961223         7.724429
# min       5.000000     0.0    25.000000      0.000000        33.000000
# 25%       8.000000     0.0    55.000000     15.865054        50.000000
# 50%      10.000000     0.0    65.000000     17.830298        55.000000
# 75%      12.000000     0.0    71.000000     21.342602        61.500000
# max      22.000000     0.0    95.000000     59.132048        78.500000
#
#        Physical-Weight  Physical-Waist_Circumference  Physical-Diastolic_BP  \
# count      1956.000000                    539.000000            1868.000000
# mean         88.929182                     27.369388              69.627409
# std          45.438935                      5.680682              13.954258
# min           0.000000                     18.000000              11.000000
# 25%          57.550000                     23.000000              61.000000
# 50%          75.800000                     26.000000              68.000000
# 75%         111.600000                     30.000000              76.000000
# max         315.000000                     50.000000             179.000000
#
#        Physical-HeartRate  Physical-Systolic_BP  FE-Max_Stage  FE-Time_Mins  \
# count         1876.000000           1868.000000    479.000000    479.000000
# mean            81.319296            117.311563      5.077244      7.559499
# std             13.810098             17.408459      1.984322      3.256167
# min             27.000000             49.000000      0.000000      0.000000
# 25%             72.000000            107.000000      4.000000      6.000000
# 50%             81.000000            115.000000      5.000000      8.000000
# 75%             90.000000            126.000000      6.000000      9.500000
# max            138.000000            203.000000     28.000000     20.000000
#
#        FE-Time_Sec   FGC-FGC_CU  FGC-FGC_CU_Zone  FGC-FGC_GSND  \
# count   479.000000  1495.000000      1468.000000    679.000000
# mean     27.125261    11.119732         0.465259     23.054094
# std      18.106062    11.792822         0.498962     11.076090
# min       0.000000     0.000000         0.000000      0.000000
# 25%      12.000000     2.000000         0.000000     15.100000
# 50%      28.000000     8.000000         0.000000     20.200000
# 75%      42.000000    16.000000         1.000000     29.050000
# max      59.000000    85.000000         1.000000    106.400000
#
#        FGC-FGC_GSND_Zone  FGC-FGC_GSD  FGC-FGC_GSD_Zone   FGC-FGC_PU  \
# count         669.000000   679.000000        669.000000  1486.000000
# mean            1.715994    24.256907          1.780269     6.330417
# std             0.601942    11.949891          0.607709     8.037151
# min             1.000000     0.000000          1.000000     0.000000
# 25%             1.000000    16.100000          1.000000     0.000000
# 50%             2.000000    21.100000          2.000000     3.000000
# 75%             2.000000    30.000000          2.000000    10.000000
# max             3.000000   123.800000          3.000000    51.000000
#
#        FGC-FGC_PU_Zone  FGC-FGC_SRL  FGC-FGC_SRL_Zone  FGC-FGC_SRR  \
# count      1460.000000  1481.000000       1456.000000  1482.000000
# mean          0.342466     8.014315          0.591346     8.127227
# std           0.474697     3.386568          0.491754     3.382664
# min           0.000000     0.000000          0.000000     0.000000
# 25%           0.000000     6.000000          0.000000     6.000000
# 50%           0.000000     8.000000          1.000000     8.000000
# 75%           1.000000    10.000000          1.000000    10.000000
# max           1.000000    20.000000          1.000000    19.000000
#
#        FGC-FGC_SRR_Zone   FGC-FGC_TL  FGC-FGC_TL_Zone  \
# count       1457.000000  1495.000000      1469.000000
# mean           0.599176     8.992441         0.755616
# std            0.490234     3.024100         0.429868
# min            0.000000     0.000000         0.000000
# 25%            0.000000     7.000000         1.000000
# 50%            1.000000     9.000000         1.000000
# 75%            1.000000    12.000000         1.000000
# max            1.000000    21.000000         1.000000
#
#        BIA-BIA_Activity_Level_num  BIA-BIA_BMC  BIA-BIA_BMI  BIA-BIA_BMR  \
# count                 1258.000000  1258.000000  1258.000000  1258.000000
# mean                     2.724960     4.563161    19.287545  1210.548410
# std                      1.035118     2.389529     4.854779   304.356156
# min                      1.000000    -6.401540    10.676600   813.397000
# 25%                      2.000000     3.105085    15.964625  1007.675000
# 50%                      3.000000     3.981260    17.912300  1115.960000
# 75%                      3.000000     5.907752    21.397400  1337.735000
# max                      5.000000    22.984500    53.924300  3987.680000
#
#        BIA-BIA_DEE  BIA-BIA_ECW  BIA-BIA_FFM  BIA-BIA_FFMI  BIA-BIA_FMI  \
# count  1258.000000  1258.000000  1258.000000   1258.000000  1258.000000
# mean   2093.847607    18.341661    71.202325     15.135579     4.151968
# std     651.437699    11.881652    32.417953      3.866611     4.347584
# min    1073.450000     1.789450    28.900400     11.322900   -66.378000
# 25%    1664.405000    10.242775    49.593575     13.376250     2.339670
# 50%    1936.875000    14.853750    61.127250     14.226350     3.513120
# 75%    2399.137500    23.557775    84.749525     15.830100     5.546943
# max    7994.080000   115.285000   367.004000     82.490200    27.685700
#
#        BIA-BIA_Fat  BIA-BIA_Frame_num  BIA-BIA_ICW  BIA-BIA_LDM  BIA-BIA_LST  \
# count  1258.000000        1258.000000  1258.000000  1258.000000  1258.000000
# mean     20.493138           1.759141    33.966061    18.894611    66.639171
# std      22.792086           0.686279    12.442233     8.553403    31.562644
# min    -217.522000           1.000000    14.489000     4.635810    23.620100
# 25%       8.878195           1.000000    25.880650    13.131000    45.779400
# 50%      15.626200           2.000000    30.154800    16.563800    57.131050
# 75%      28.184450           2.000000    39.050100    22.930425    80.556675
# max     153.820000           3.000000   152.738000    98.981300   355.058000
#
#        BIA-BIA_SMM  BIA-BIA_TBW  PAQ_A-PAQ_A_Total  PAQ_C-PAQ_C_Total  \
# count  1258.000000  1258.000000         272.000000        1083.000000
# mean     33.407844    52.307723           2.323018           2.654404
# std      19.579849    24.253591           0.880279           0.808210
# min       4.655730    20.589200           0.660000           0.580000
# 25%      21.239225    36.181500           1.577500           2.075000
# 50%      27.489950    45.113300           2.185000           2.610000
# 75%      39.740575    62.090750           2.970000           3.220500
# max     254.611000   268.022000           4.710000           4.790000
#
#        PCIAT-PCIAT_01  PCIAT-PCIAT_02  PCIAT-PCIAT_03  PCIAT-PCIAT_04  \
# count     1737.000000     1738.000000     1736.000000     1737.000000
# mean         2.501439        2.267549        2.535138        0.914220
# std          1.690010        1.726323        1.620093        1.265507
# min          0.000000        0.000000        0.000000        0.000000
# 25%          1.000000        1.000000        1.000000        0.000000
# 50%          2.000000        2.000000        3.000000        0.000000
# 75%          4.000000        4.000000        4.000000        1.000000
# max          5.000000        5.000000        5.000000        5.000000
#
#        PCIAT-PCIAT_05  PCIAT-PCIAT_06  PCIAT-PCIAT_07  PCIAT-PCIAT_08  \
# count     1733.000000     1737.000000     1735.000000     1737.000000
# mean         2.421812        1.115717        0.547550        1.286701
# std          1.737153        1.321076        1.003979        1.382749
# min          0.000000        0.000000        0.000000        0.000000
# 25%          1.000000        0.000000        0.000000        0.000000
# 50%          2.000000        1.000000        0.000000        1.000000
# 75%          4.000000        2.000000        1.000000        2.000000
# max          5.000000        5.000000        5.000000        5.000000
#
#        PCIAT-PCIAT_09  PCIAT-PCIAT_10  PCIAT-PCIAT_11  PCIAT-PCIAT_12  \
# count     1738.000000     1738.000000     1738.000000     1737.000000
# mean         1.061565        1.365362        1.698504        0.243523
# std          1.268822        1.373529        1.575579        0.532357
# min          0.000000        0.000000        0.000000        0.000000
# 25%          0.000000        0.000000        0.000000        0.000000
# 50%          1.000000        1.000000        2.000000        0.000000
# 75%          2.000000        2.000000        3.000000        0.000000
# max          5.000000        5.000000        5.000000        5.000000
#
#        PCIAT-PCIAT_13  PCIAT-PCIAT_14  PCIAT-PCIAT_15  PCIAT-PCIAT_16  \
# count     1735.000000     1738.000000     1737.000000     1733.000000
# mean         1.439193        1.055236        1.622337        1.563185
# std          1.466924        1.324387        1.562863        1.545374
# min          0.000000        0.000000        0.000000        0.000000
# 25%          0.000000        0.000000        0.000000        0.000000
# 50%          1.000000        1.000000        1.000000        1.000000
# 75%          2.000000        2.000000        3.000000        2.000000
# max          5.000000        5.000000        5.000000        5.000000
#
#        PCIAT-PCIAT_17  PCIAT-PCIAT_18  PCIAT-PCIAT_19  PCIAT-PCIAT_20  \
# count     1731.000000     1734.000000     1735.000000     1738.000000
# mean         1.740035        1.741061        1.265706        1.004603
# std          1.494695        1.583006        1.412277        1.237014
# min          0.000000        0.000000        0.000000        0.000000
# 25%          0.000000        0.000000        0.000000        0.000000
# 50%          2.000000        1.000000        1.000000        1.000000
# 75%          3.000000        3.000000        2.000000        1.000000
# max          5.000000        5.000000        5.000000        5.000000
#
#        PCIAT-PCIAT_Total  SDS-SDS_Total_Raw  SDS-SDS_Total_T  \
# count        1739.000000        1663.000000      1662.000000
# mean           29.338125          41.247144        57.947653
# std            20.829645          10.717110        13.556012
# min             0.000000          24.000000        38.000000
# 25%            13.000000          33.000000        47.000000
# 50%            28.000000          39.000000        55.000000
# 75%            43.000000          47.000000        66.000000
# max            92.000000          93.000000       100.000000
#
#        PreInt_EduHx-computerinternet_hoursday          sii
# count                             2096.000000  1739.000000
# mean                                 1.061069     0.638873
# std                                  1.084097     0.798882
# min                                  0.000000     0.000000
# 25%                                  0.000000     0.000000
# 50%                                  1.000000     0.000000
# 75%                                  2.000000     1.000000
# max                                  3.000000     3.000000

# %%
pd.set_option('display.max_columns', None)  
female_df.describe(include='all')
# Out:
#               id Enrol_Season         Age    Sex CGAS-Season  CGAS-Score  \
# count        577          577  577.000000  577.0         577  577.000000
# unique       577            4         NaN    NaN           4         NaN
# top     fefaffe0       Spring         NaN    NaN      Spring         NaN
# freq           1          168         NaN    NaN         178         NaN
# mean         NaN          NaN   10.365685    1.0         NaN   65.930676
# std          NaN          NaN    3.489031    0.0         NaN   12.254763
# min          NaN          NaN    5.000000    1.0         NaN   30.000000
# 25%          NaN          NaN    8.000000    1.0         NaN   60.000000
# 50%          NaN          NaN   10.000000    1.0         NaN   65.000000
# 75%          NaN          NaN   13.000000    1.0         NaN   75.000000
# max          NaN          NaN   21.000000    1.0         NaN   92.000000
#
#        Physical-Season  Physical-BMI  Physical-Height  Physical-Weight  \
# count              577    576.000000       576.000000       576.000000
# unique               4           NaN              NaN              NaN
# top             Spring           NaN              NaN              NaN
# freq               169           NaN              NaN              NaN
# mean               NaN     19.311288        55.394410        88.505208
# std                NaN      5.167626         6.943626        40.696178
# min                NaN      9.959167        40.000000        36.600000
# 25%                NaN     15.809349        50.000000        57.200000
# 50%                NaN     17.883078        55.000000        77.200000
# 75%                NaN     21.318035        62.000000       112.200000
# max                NaN     44.835548        71.000000       251.200000
#
#         Physical-Waist_Circumference  Physical-Diastolic_BP  \
# count                      91.000000             570.000000
# unique                           NaN                    NaN
# top                              NaN                    NaN
# freq                             NaN                    NaN
# mean                       25.901099              69.819298
# std                         5.302106              13.330224
# min                        19.000000              34.000000
# 25%                        22.000000              61.000000
# 50%                        25.000000              68.000000
# 75%                        28.000000              76.000000
# max                        46.000000             128.000000
#
#         Physical-HeartRate  Physical-Systolic_BP FE-Season  FE-Max_Stage  \
# count           571.000000            570.000000       287    202.000000
# unique                 NaN                   NaN         4           NaN
# top                    NaN                   NaN    Spring           NaN
# freq                   NaN                   NaN        92           NaN
# mean             82.966725            116.596491       NaN      4.856436
# std              13.439688             16.913571       NaN      2.195469
# min              33.000000             78.000000       NaN      1.000000
# 25%              74.000000            106.000000       NaN      4.000000
# 50%              83.000000            113.000000       NaN      5.000000
# 75%              92.000000            123.750000       NaN      6.000000
# max             123.000000            194.000000       NaN     26.000000
#
#         FE-Time_Mins  FE-Time_Sec FGC-Season  FGC-FGC_CU  FGC-FGC_CU_Zone  \
# count     199.000000   199.000000        562  476.000000       467.000000
# unique           NaN          NaN          4         NaN              NaN
# top              NaN          NaN     Spring         NaN              NaN
# freq             NaN          NaN        160         NaN              NaN
# mean        7.050251    29.798995        NaN   12.336134         0.576017
# std         3.076054    16.639365        NaN   11.943747         0.494718
# min         0.000000     0.000000        NaN    0.000000         0.000000
# 25%         5.000000    16.000000        NaN    5.000000         0.000000
# 50%         7.000000    30.000000        NaN   10.000000         1.000000
# 75%         9.000000    45.000000        NaN   15.000000         1.000000
# max        16.000000    59.000000        NaN  115.000000         1.000000
#
#         FGC-FGC_GSND  FGC-FGC_GSND_Zone  FGC-FGC_GSD  FGC-FGC_GSD_Zone  \
# count     215.000000         214.000000   215.000000        215.000000
# unique           NaN                NaN          NaN               NaN
# top              NaN                NaN          NaN               NaN
# freq             NaN                NaN          NaN               NaN
# mean       21.283256           2.023364    22.103256          2.134884
# std        10.999528           0.576875     9.226994          0.576358
# min         0.000000           1.000000     5.100000          1.000000
# 25%        15.350000           2.000000    16.750000          2.000000
# 50%        19.300000           2.000000    21.300000          2.000000
# 75%        24.450000           2.000000    25.800000          2.000000
# max       124.000000           3.000000    88.800000          3.000000
#
#         FGC-FGC_PU  FGC-FGC_PU_Zone  FGC-FGC_SRL  FGC-FGC_SRL_Zone  \
# count   472.000000       463.000000   477.000000        468.000000
# unique         NaN              NaN          NaN               NaN
# top            NaN              NaN          NaN               NaN
# freq           NaN              NaN          NaN               NaN
# mean      4.694915         0.341253    10.189203          0.728632
# std       5.815286         0.474643     2.768313          0.445141
# min       0.000000         0.000000     0.000000          0.000000
# 25%       0.000000         0.000000     8.500000          0.000000
# 50%       2.000000         0.000000    10.500000          1.000000
# 75%       7.000000         1.000000    12.000000          1.000000
# max      30.000000         1.000000    19.000000          1.000000
#
#         FGC-FGC_SRR  FGC-FGC_SRR_Zone  FGC-FGC_TL  FGC-FGC_TL_Zone BIA-Season  \
# count    477.000000        468.000000  477.000000       468.000000        577
# unique          NaN               NaN         NaN              NaN          4
# top             NaN               NaN         NaN              NaN     Summer
# freq            NaN               NaN         NaN              NaN        196
# mean      10.282600          0.709402    9.553459         0.835470        NaN
# std        2.822669          0.454524    2.728963         0.371152        NaN
# min        0.000000          0.000000    0.000000         0.000000        NaN
# 25%        8.500000          0.000000    8.000000         1.000000        NaN
# 50%       10.500000          1.000000   10.000000         1.000000        NaN
# 75%       12.000000          1.000000   12.000000         1.000000        NaN
# max       19.000000          1.000000   20.000000         1.000000        NaN
#
#         BIA-BIA_Activity_Level_num  BIA-BIA_BMC  BIA-BIA_BMI  BIA-BIA_BMR  \
# count                   577.000000   577.000000   577.000000   577.000000
# unique                         NaN          NaN          NaN          NaN
# top                            NaN          NaN          NaN          NaN
# freq                           NaN          NaN          NaN          NaN
# mean                      2.571924     4.430236    19.405366  1151.517808
# std                       1.016586     2.841908     5.375376   223.788210
# min                       1.000000    -7.789610    11.468500   854.838000
# 25%                       2.000000     2.674060    15.768600   999.121000
# 50%                       3.000000     3.880170    17.882100  1104.010000
# 75%                       3.000000     5.213660    21.397300  1273.550000
# max                       5.000000    29.463000    48.375400  3600.180000
#
#         BIA-BIA_DEE  BIA-BIA_ECW  BIA-BIA_FFM  BIA-BIA_FFMI  BIA-BIA_FMI  \
# count    577.000000   577.000000   577.000000    577.000000   577.000000
# unique          NaN          NaN          NaN           NaN          NaN
# top             NaN          NaN          NaN           NaN          NaN
# freq            NaN          NaN          NaN           NaN          NaN
# mean    1826.629480    20.037310    64.914777     14.497091     4.908276
# std      445.135068     9.689228    23.836391      2.511287     4.516646
# min     1111.290000     4.883230    33.314500     12.292900   -28.929300
# 25%     1523.280000    12.815500    48.682500     13.461900     2.151160
# 50%     1743.000000    17.945400    59.854700     13.929300     3.957020
# 75%     2051.980000    26.119900    77.912500     14.844300     6.604350
# max     5717.710000   104.347000   325.730000     53.379900    28.251500
#
#         BIA-BIA_Fat  BIA-BIA_Frame_num  BIA-BIA_ICW  BIA-BIA_LDM  BIA-BIA_LST  \
# count    577.000000         577.000000   577.000000   577.000000   577.000000
# unique          NaN                NaN          NaN          NaN          NaN
# top             NaN                NaN          NaN          NaN          NaN
# freq            NaN                NaN          NaN          NaN          NaN
# mean      23.773042           1.729636    27.755232    17.122235    60.484542
# std       25.378519           0.671626     8.024562     6.936506    23.953577
# min     -176.530000           1.000000    17.555000     5.856400    23.947300
# 25%        7.870970           1.000000    22.446600    12.463400    43.712000
# 50%       17.509600           2.000000    26.162900    16.054400    55.746100
# 75%       33.209000           2.000000    31.668500    21.412000    73.780700
# max      121.166000           3.000000   125.694000    95.688200   315.215000
#
#         BIA-BIA_SMM  BIA-BIA_TBW PAQ_A-Season  PAQ_A-PAQ_A_Total PAQ_C-Season  \
# count    577.000000   577.000000           85          85.000000          306
# unique          NaN          NaN            4                NaN            4
# top             NaN          NaN       Winter                NaN       Spring
# freq            NaN          NaN           28                NaN           98
# mean      29.959499    47.792541          NaN           2.074153          NaN
# std       14.779026    17.527360          NaN           0.771259          NaN
# min       12.726700    23.292800          NaN           0.990000          NaN
# 25%       21.013400    35.190400          NaN           1.490000          NaN
# 50%       27.130300    44.621600          NaN           1.930000          NaN
# 75%       36.012500    57.662800          NaN           2.600000          NaN
# max      223.449000   230.042000          NaN           4.420000          NaN
#
#         PAQ_C-PAQ_C_Total PCIAT-Season  PCIAT-PCIAT_01  PCIAT-PCIAT_02  \
# count          306.000000          569      569.000000      569.000000
# unique                NaN            4             NaN             NaN
# top                   NaN       Spring             NaN             NaN
# freq                  NaN          169             NaN             NaN
# mean             2.457497          NaN        2.154657        1.961336
# std              0.688749          NaN        1.599070        1.647207
# min              0.990000          NaN        0.000000        0.000000
# 25%              1.932500          NaN        1.000000        0.000000
# 50%              2.440000          NaN        2.000000        2.000000
# 75%              2.900000          NaN        3.000000        3.000000
# max              4.210000          NaN        5.000000        5.000000
#
#         PCIAT-PCIAT_03  PCIAT-PCIAT_04  PCIAT-PCIAT_05  PCIAT-PCIAT_06  \
# count       568.000000      568.000000      569.000000      569.000000
# unique             NaN             NaN             NaN             NaN
# top                NaN             NaN             NaN             NaN
# freq               NaN             NaN             NaN             NaN
# mean          2.126761        0.697183        2.061511        0.989455
# std           1.518187        1.059030        1.642764        1.207326
# min           0.000000        0.000000        0.000000        0.000000
# 25%           1.000000        0.000000        1.000000        0.000000
# 50%           2.000000        0.000000        2.000000        1.000000
# 75%           3.000000        1.000000        3.000000        1.000000
# max           5.000000        5.000000        5.000000        5.000000
#
#         PCIAT-PCIAT_07  PCIAT-PCIAT_08  PCIAT-PCIAT_09  PCIAT-PCIAT_10  \
# count       568.000000       567.00000      567.000000      568.000000
# unique             NaN             NaN             NaN             NaN
# top                NaN             NaN             NaN             NaN
# freq               NaN             NaN             NaN             NaN
# mean          0.663732         1.17284        1.044092        1.151408
# std           1.164414         1.28257        1.246832        1.256362
# min           0.000000         0.00000        0.000000        0.000000
# 25%           0.000000         0.00000        0.000000        0.000000
# 50%           0.000000         1.00000        1.000000        1.000000
# 75%           1.000000         2.00000        2.000000        2.000000
# max           5.000000         5.00000        5.000000        5.000000
#
#         PCIAT-PCIAT_11  PCIAT-PCIAT_12  PCIAT-PCIAT_13  PCIAT-PCIAT_14  \
# count       569.000000      569.000000      568.000000      567.000000
# unique             NaN             NaN             NaN             NaN
# top                NaN             NaN             NaN             NaN
# freq               NaN             NaN             NaN             NaN
# mean          1.557118        0.242531        1.156690        0.961199
# std           1.474187        0.500934        1.296485        1.233475
# min           0.000000        0.000000        0.000000        0.000000
# 25%           0.000000        0.000000        0.000000        0.000000
# 50%           1.000000        0.000000        1.000000        1.000000
# 75%           3.000000        0.000000        2.000000        2.000000
# max           5.000000        5.000000        5.000000        5.000000
#
#         PCIAT-PCIAT_15  PCIAT-PCIAT_16  PCIAT-PCIAT_17  PCIAT-PCIAT_18  \
# count       567.000000      568.000000      568.000000      568.000000
# unique             NaN             NaN             NaN             NaN
# top                NaN             NaN             NaN             NaN
# freq               NaN             NaN             NaN             NaN
# mean          1.282187        1.253521        1.401408        1.401408
# std           1.312383        1.374685        1.312320        1.441682
# min           0.000000        0.000000        0.000000        0.000000
# 25%           0.000000        0.000000        0.000000        0.000000
# 50%           1.000000        1.000000        1.000000        1.000000
# 75%           2.000000        2.000000        2.000000        2.000000
# max           5.000000        5.000000        5.000000        5.000000
#
#         PCIAT-PCIAT_19  PCIAT-PCIAT_20  PCIAT-PCIAT_Total SDS-Season  \
# count       568.000000      568.000000         569.000000        516
# unique             NaN             NaN                NaN          4
# top                NaN             NaN                NaN     Spring
# freq               NaN             NaN                NaN        153
# mean          0.966549        0.822183          25.031634        NaN
# std           1.182146        1.086262          19.502773        NaN
# min           0.000000        0.000000           0.000000        NaN
# 25%           0.000000        0.000000           9.000000        NaN
# 50%           1.000000        1.000000          23.000000        NaN
# 75%           1.000000        1.000000          37.000000        NaN
# max           5.000000        5.000000          93.000000        NaN
#
#         SDS-SDS_Total_Raw  SDS-SDS_Total_T PreInt_EduHx-Season  \
# count          516.000000       516.000000                 577
# unique                NaN              NaN                   4
# top                   NaN              NaN              Spring
# freq                  NaN              NaN                 163
# mean            40.517442        57.069767                 NaN
# std              9.913494        12.639089                 NaN
# min             26.000000        38.000000                 NaN
# 25%             33.000000        47.000000                 NaN
# 50%             38.000000        54.000000                 NaN
# 75%             46.000000        64.000000                 NaN
# max             84.000000       100.000000                 NaN
#
#         PreInt_EduHx-computerinternet_hoursday         sii
# count                               565.000000  569.000000
# unique                                     NaN         NaN
# top                                        NaN         NaN
# freq                                       NaN         NaN
# mean                                  0.964602    0.478032
# std                                   1.084458    0.726723
# min                                   0.000000    0.000000
# 25%                                   0.000000    0.000000
# 50%                                   0.000000    0.000000
# 75%                                   2.000000    1.000000
# max                                   3.000000    3.000000
